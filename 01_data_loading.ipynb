# %%
import json

# %%
def load (filename):
   with open(filename,"r") as f:
      data=json.load(f)
   return data

# %%
data=load("data.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
def dispay(data):
    print("Information\n")
    for i in data['users']:
        print(f"{i["name"]} having id {i["id"]} is friends with {i["friends"]} havings liking pages of{i["liked_pages"]}") 
    for j in data['pages']:
        print(f"{j["id"]} refers to {j["name"]}")
dispay(data)
# Out:
# Information
#
# Amit having id 1 is friends with [2, 3] havings liking pages of[101]
# Priya having id 2 is friends with [1, 4] havings liking pages of[102]
# Rahul having id 3 is friends with [1] havings liking pages of[101, 103]
# Sara having id 4 is friends with [2] havings liking pages of[104]
# 101 refers to Python Developers
# 102 refers to Data Science Enthusiasts
# 103 refers to AI & ML Community
# 104 refers to Web Dev Hub
